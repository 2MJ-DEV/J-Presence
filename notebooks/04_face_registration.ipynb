# %% [markdown]
# # 04 - Enregistrement d'un étudiant
# Prototype de capture : un seul visage par image, puis moyenne des embeddings.

# %%
from pathlib import Path
import sys
import collections.abc
from typing import Protocol

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

if not hasattr(collections.abc, "Protocol"):
    collections.abc.Protocol = Protocol

import numpy as np
from src.face.registration import StudentProfile, register_student_from_frames
# Le detector réel est InsightFaceDetector(get_settings().model_name).
# Les frames doivent venir de la webcam et contenir un seul visage.

# %%
profile = StudentProfile('Nom Exemple', 'BAC 4 IA', 'IA', 'PERSO')
# with SessionLocal() as db:
#     student = register_student_from_frames(db, profile, detector, frames, minimum_captures=3)
#     print(student.id, len(student.face_embedding))
