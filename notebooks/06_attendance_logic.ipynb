# %% [markdown]
# # 06 - Logique entrée / sortie
# Tester le service métier sans webcam : entrée, cooldown, sortie et étudiant inconnu.

# %%
from datetime import datetime
from src.attendance.service import AttendanceService
# Préparer une Session SQLite et un Student avant l'exécution.
# service = AttendanceService(db, cooldown_seconds=10)
# moment = datetime(2026, 9, 22, 8, 2)
# print(service.record_detection(student.id, moment).action)
# print(service.record_detection(student.id, moment.replace(second=5)).action)
# print(service.record_detection(student.id, moment.replace(hour=12, minute=17)).action)
