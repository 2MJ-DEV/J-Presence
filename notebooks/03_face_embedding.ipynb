# %% [markdown]
# # 03 - Embeddings faciaux
# Ce notebook extrait et compare deux embeddings avec le code de `src/`.

# %%
from src.config.settings import get_settings
from src.face.detector import InsightFaceDetector
# detector = InsightFaceDetector(get_settings().model_name)
# detections = detector.detect(frame_bgr)
# embedding = detections[0].embedding

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
from src.face.embedding import cosine_similarity, normalize_embedding

first = normalize_embedding(np.random.default_rng(1).normal(size=512))
second = normalize_embedding(np.random.default_rng(2).normal(size=512))
print('dimension:', first.shape[0])
print('similarity:', cosine_similarity(first, second))
