# %% [markdown]
# # 07 - Pipeline complet
# Le script de production correspondant est `scripts/run_camera.py`. Ce notebook montre les étapes sans cacher les responsabilités.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.attendance.service import AttendanceService
from src.config.settings import get_settings
from src.database.connection import SessionLocal
from src.database.repository import list_students
from src.face.detector import InsightFaceDetector

settings = get_settings()
detector = InsightFaceDetector(settings.model_name)
with SessionLocal() as db:
    service = AttendanceService(db, settings.cooldown_seconds)
    students = list_students(db)
    # resultats = service.process_frame(frame_bgr, detector, students, settings.face_recognition_threshold)
    print('Pipeline prêt :', len(students), 'étudiants connus')

# %% [markdown]
# Pour lancer la boucle webcam réelle : `python -m scripts.run_camera`. Les visages inconnus sont affichés mais jamais enregistrés.
